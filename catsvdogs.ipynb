# %%
import random

# %%
nCats = 40nDogs = 60nVoters = 150votes = []for i in range(nVoters):    if random.random() < 0.5:        vote = ('C'+str(random.randint(1,nCats)), 'D'+str(random.randint(1, nDogs)))    else:        vote = ('D'+str(random.randint(1,nDogs)), 'C'+str(random.randint(1, nCats)))        votes.append(vote)

# %%
print votes
# Out:
# [('D31', 'C16'), ('D3', 'C26'), ('D26', 'C22'), ('D21', 'C32'), ('C33', 'D9'), ('C17', 'D16'), ('C28', 'D29'), ('D37', 'C1'), ('C28', 'D53'), ('D44', 'C33'), ('D22', 'C39'), ('D17', 'C36'), ('D58', 'C28'), ('D3', 'C6'), ('D32', 'C25'), ('D56', 'C7'), ('C11', 'D3'), ('D11', 'C19'), ('D12', 'C28'), ('C19', 'D57'), ('D42', 'C20'), ('D36', 'C11'), ('C4', 'D29'), ('D37', 'C8'), ('C12', 'D54'), ('C25', 'D29'), ('D32', 'C39'), ('C16', 'D4'), ('C6', 'D31'), ('D26', 'C1'), ('C12', 'D47'), ('D4', 'C22'), ('C21', 'D27'), ('D30', 'C11'), ('C28', 'D44'), ('D52', 'C32'), ('C11', 'D59'), ('D30', 'C5'), ('D41', 'C25'), ('C2', 'D56'), ('D5', 'C31'), ('C19', 'D35'), ('C3', 'D16'), ('C7', 'D21'), ('D25', 'C24'), ('C22', 'D46'), ('C6', 'D48'), ('D48', 'C28'), ('D56', 'C28'), ('C25', 'D6'), ('C27', 'D33'), ('D41', 'C38'), ('C32', 'D38'), ('D19', 'C34'), ('C37', 'D5'), ('D19', 'C24'), ('D11', 'C3'), ('D39', 'C24'), ('C13', 'D54'), ('C5', 'D27'), ('D48', 'C6'), ('C34', 'D11'), ('D7', 'C15'), ('D1', 'C22'),
# ...
